# %% [markdown]
# # Machine Learning KNN - First training

# %% [markdown]
# ### Stores the 3 types of datas in variables

# %%
import pandas as pd
import sklearn as skl
import matplotlib.pyplot as plt
import seaborn as sns

iris_df = pd.read_csv("iris.csv")

iris_df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_df_2 = iris_df.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %%
# species_df = iris_df['Species'].value_counts()
visualize_board = sns.load_dataset('iris')
visualize_board.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
bar_visu = sns.scatterplot(data=visualize_board, x="sepal_width", y="petal_width", hue="species")
print(bar_visu)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
bar_visu = sns.scatterplot(data=visualize_board)
